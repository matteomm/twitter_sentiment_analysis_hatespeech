# %%
from __future__ import print_function
import pandas as pd
import matplotlib.pyplot as plt 
import datetime  
from nltk.tokenize import word_tokenize  
import seaborn as sns
import scipy.stats as stats
from scipy.stats import ttest_ind
import numpy as np
import re
import mysql.connector

import matplotlib.pyplot as plt
from nltk.tokenize import TweetTokenizer

import tweepy
# importing relevant packages to receive Twitter streams
from tweepy import Stream
from tweepy.streaming import StreamListener
# credentials taken from the twitter API
import credentials
import json

from dateutil import parser

# %%
# importing relevant packages to receive Twitter streams
from tweepy import Stream
from tweepy.streaming import StreamListener
# credentials taken from the twitter API
import credentials

# %%
# credentials to access Twitter API
auth  = tweepy.OAuthHandler(credentials.API_KEY, \
                            credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN,  \
                      credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
# create function to strip emojis from the stream
def removeEmoj(text):
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
# create a function to store data in a MYSQL database
def store_data(id_str , created_at, text, processed):
    db=mysql.connector.connect(host="localhost", user="root", passwd="password", db="twitter_2", charset="utf8")
    cursor = db.cursor()
    insert_query = "INSERT INTO twitter_2 (id_str, created_at, text, processed) VALUES (%s, %s, %s, %s)"
    cursor.execute(insert_query, (id_str , created_at, text,processed))
    db.commit()
    cursor.close()
    db.close()
    return

# %%
# connecting the MYSQL database
db = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="password",
    database="twitter_2",
    charset = 'utf8'
)

# %%
# check that it's connected
mycursor = db.cursor()
mycursor.execute("SHOW TABLES")

for x in mycursor:
    print(x)
# Out:
# ('twitter_2',)

# %%
# customising the stream listener to add extra conditions
class MyListener(StreamListener):
 

            
            
            
    def on_data(self, data):
        
        try:
           # Decode the JSON from Twitter
            datajson = json.loads(data)
    
            
             
            
                
            #grab the wanted data from the Tweet
            id_str = datajson['id_str']
            print(1)
            created_at =parser.parse(datajson['created_at'])
#             created_at = datajson['created_at']
            print(2)
            text = datajson['text']
            text = removeEmoj(text)
            
            print(3)
#             user_created_at = parser.parse(datajson['user_created_at']) 
            processed = -1
            print(4)
#             user_location = datajson['user_location']
            
            print(5)

   

            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(text))
            
            #insert the data into the MySQL database
            store_data(id_str , created_at, text, processed)
            print(datajson)
        
        except Exception as e:
            print(e)

# %%
MyListener = MyListener(api=tweepy.API(wait_on_rate_limit=True))
myStream = tweepy.Stream(auth = api.auth, listener = MyListener )
myStream.filter(languages=["en"], track = ['#coronavirus'])
# Out:
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @Telegraph: A factory in Colombia is making hospital beds that can be turned into a coffin if the patient dies
#
# These dual-purpose beds
# {'created_at': 'Sat May 16 14:22:19 +0000 2020', 'id': 1261663272719339522, 'id_str': '1261663272719339522', 'text': 'RT @Telegraph: A factory in Colombia is making hospital beds that can be turned into a coffin if the patient dies\n\nThese dual-purpose beds…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 193743784, 'id_str': '193743784', 'name': 'Mosh Ben Sadiqim', 'screen_name': 'tutmosh', 'location': 'Barcelona', 'url': None, 'description': 'A minha história é talvez\nÉ talvez igual a tua...\nE que ficou desapontado, como é comum no seu tempo\nE que ficou apaixonado e violento como eu como você.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 282, 'friends_count': 1821, 'listed_count': 2, 'favourites_count': 52902, 'statuses_count': 27567, 'created_at': 'Wed Sep 22 15:50:20 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif', 'profile_background_tile': False, 'profile_link_color': '91D2FA', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1252427944460349451/N-MRWJhj_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252427944460349451/N-MRWJhj_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/193743784/1587856786', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu May 14 15:04:28 +0000 2020', 'id': 1260949102617075712, 'id_str': '1260949102617075712', 'text': 'A factory in Colombia is making hospital beds that can be turned into a coffin if the patient dies\n\nThese dual-purp… https://t.co/uvRtS3A2gQ', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 16343974, 'id_str': '16343974', 'name': 'The Telegraph', 'screen_name': 'Telegraph', 'location': 'London, UK', 'url': 'http://www.telegraph.co.uk/?WT.mc_id=tw', 'description': 'Think ahead with the latest news, comment, analysis and video', 'translator_type': 'regular', 'protected': False, 'verified': True, 'followers_count': 2883947, 'friends_count': 752, 'listed_count': 17430, 'favourites_count': 272, 'statuses_count': 376835, 'created_at': 'Thu Sep 18 06:50:54 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '5F5653', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': True, 'profile_link_color': '3B94D9', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F4F4F0', 'profile_text_color': '000000', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/943090005723041792/2cjxINlJ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/943090005723041792/2cjxINlJ_normal.jpg', 'profile_bann ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @sageusa: Despite being more at risk of contracting #COVID19, #LGBTelders and our community face #discrimination in hospitals and health
# {'created_at': 'Sat May 16 14:22:19 +0000 2020', 'id': 1261663273889529857, 'id_str': '1261663273889529857', 'text': 'RT @sageusa: Despite being more at risk of contracting #COVID19, #LGBTelders and our community face #discrimination in hospitals and health…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 823252701421125635, 'id_str': '823252701421125635', 'name': 'One American', 'screen_name': '1silveramerican', 'location': None, 'url': 'http://www.silverlivesmatter.us', 'description': 'One Silver American #SilverLivesMatter #PeoplePlease #ApprenticePrez #BeBetter #StandWithFeds #BeLikeBucky #SHErO', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 44, 'friends_count': 1407, 'listed_count': 0, 'favourites_count': 5694, 'statuses_count': 5261, 'created_at': 'Sun Jan 22 19:35:14 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/823293649073029120/j6yMXp_E_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/823293649073029120/j6yMXp_E_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/823252701421125635/1485370653', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat May 16 14:19:00 +0000 2020', 'id': 1261662439940251653, 'id_str': '1261662439940251653', 'text': 'Despite being more at risk of contracting #COVID19, #LGBTelders and our community face #discrimination in hospitals… https://t.co/H0oIz6hSuy', 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 113523341, 'id_str': '113523341', 'name': 'SAGE USA', 'screen_name': 'sageusa', 'location': 'New York, NY', 'url': 'http://sageusa.org', 'description': "We are the world's largest and oldest organization dedicated to improving the lives of LGBT older adults.", 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 11347, 'friends_count': 2113, 'listed_count': 412, 'favourites_count': 7376, 'statuses_count': 20248, 'created_at': 'Fri Feb 12 02:36:46 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '0C79BE', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'E7ECF0', 'profile_text_color': '004B96', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/852151339375370240/-IBJzF-U_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/852151339375370240/-IBJzF-U_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/113523341/1566397598', 'default_profile': False, 'default_profile_image': False, 'foll ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @JohnRLottJr: The US is Dramatically Over counting #Coronavirus Deaths
# "Deaths that have absolutely nothing to do with the Coronavirus c
# {'created_at': 'Sat May 16 14:22:19 +0000 2020', 'id': 1261663274518450179, 'id_str': '1261663274518450179', 'text': 'RT @JohnRLottJr: The US is Dramatically Over counting #Coronavirus Deaths\n"Deaths that have absolutely nothing to do with the Coronavirus c…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 434379066, 'id_str': '434379066', 'name': 'DA', 'screen_name': 'gigabein', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 21, 'friends_count': 189, 'listed_count': 0, 'favourites_count': 2834, 'statuses_count': 911, 'created_at': 'Sun Dec 11 19:50:18 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1213840003610095616/scQGAcoM_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1213840003610095616/scQGAcoM_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/434379066/1578237280', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat May 16 09:24:31 +0000 2020', 'id': 1261588329319018496, 'id_str': '1261588329319018496', 'text': 'The US is Dramatically Over counting #Coronavirus Deaths\n"Deaths that have absolutely nothing to do with the Corona… https://t.co/pkFLODtVFm', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 539566673, 'id_str': '539566673', 'name': 'John R Lott Jr.', 'screen_name': 'JohnRLottJr', 'location': None, 'url': 'http://crimeresearch.org', 'description': 'President,Crime Prevention Research Cntr.Author The War on Guns;More Guns,Less Crime(Univ Chi Press,3rd ed);9 books.100+acad articles.FoxNews columnist.PhD econ', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 30711, 'friends_count': 513, 'listed_count': 449, 'favourites_count': 2368, 'statuses_count': 20184, 'created_at': 'Thu Mar 29 01:53:09 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/935389293060743168/lkqhd8YE_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/935389293060743168/lkqhd8YE_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/539566673/1407909234', 'default_profile': False, 'default_profile_image': False, 'following' ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at 2020 Winter excess deaths 0.035%
# 2018 Winter excess deaths 0.041%
#
# #endthelockdownuk
#
#  https://t.co/fOha5DDfm9
# {'created_at': 'Sat May 16 14:22:19 +0000 2020', 'id': 1261663274363469829, 'id_str': '1261663274363469829', 'text': '2020 Winter excess deaths 0.035%\n2018 Winter excess deaths 0.041%\n\n#endthelockdownuk\n\n https://t.co/fOha5DDfm9', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 143594509, 'id_str': '143594509', 'name': 'Rafal Cala', 'screen_name': 'Rafal_Cala', 'location': 'Bristol, England', 'url': None, 'description': 'Accountant, MA Philosophy, Pro-EU left-wing liberal, Covid-19 truther  \n\n#endthelockdownuk', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 92, 'friends_count': 230, 'listed_count': 2, 'favourites_count': 5683, 'statuses_count': 1085, 'created_at': 'Thu May 13 22:21:50 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1256880236966432768/RxZegZbl_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256880236966432768/RxZegZbl_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/143594509/1588541282', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1261631396831014916, 'quoted_status_id_str': '1261631396831014916', 'quoted_status': {'created_at': 'Sat May 16 12:15:39 +0000 2020', 'id': 1261631396831014916, 'id_str': '1261631396831014916', 'text': 'Do you know the ACTUAL death rate in Europe for #Coronavirus - versus excess deaths in 2018 Winter Season?\n\nShouldn… https://t.co/tA3PAbyp2T', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2383882980, 'id_str': '2383882980', 'name': 'Ivor Cummins', 'screen_name': 'FatEmperor', 'location': 'Ireland', 'url': 'http://www.thefatemperor.com', 'description': 'Technical Manager / Team Leader, Biochemical Engineer, Complex Problem Solving Specialist, Technologist #Biochemistry, #Nutrition, #LCHF, #CAC, #CVD, #RootCause', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 51754, 'friends_count': 10853, 'listed_count': 760, 'favourites_count': 71738, 'statuses_count': 58339, 'created_at': 'Tue Mar 11 15:31:46 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1230186640796258304/agAerzps_normal.jpg', 'profile_image_url_https': 'https://pbs.tw ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @Saudi_Gazette: #BREAKING: #SaudiArabia reports 10 new deaths due to #coronavirus, raising the death toll to 302. https://t.co/ZuzF528kch
# {'created_at': 'Sat May 16 14:22:20 +0000 2020', 'id': 1261663275340771334, 'id_str': '1261663275340771334', 'text': 'RT @Saudi_Gazette: #BREAKING: #SaudiArabia reports 10 new deaths due to #coronavirus, raising the death toll to 302. https://t.co/ZuzF528kch', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3684767276, 'id_str': '3684767276', 'name': 'Hasrat Abbas Awan (Hassy)', 'screen_name': 'HAAwan9', 'location': 'Dammam, KSA', 'url': None, 'description': '🇵🇰\nProfessional Food Technologist (Food Safety Trainer)', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 177, 'friends_count': 9, 'listed_count': 3, 'favourites_count': 27074, 'statuses_count': 6439, 'created_at': 'Fri Sep 25 19:41:18 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_tile': False, 'profile_link_color': '981CEB', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1256679418262622209/NLjk0r-k_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256679418262622209/NLjk0r-k_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3684767276/1588450694', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat May 16 12:47:45 +0000 2020', 'id': 1261639474506801154, 'id_str': '1261639474506801154', 'text': '#BREAKING: #SaudiArabia reports 10 new deaths due to #coronavirus, raising the death toll to 302. https://t.co/ZuzF528kch', 'display_text_range': [0, 97], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 567289542, 'id_str': '567289542', 'name': 'Saudi Gazette', 'screen_name': 'Saudi_Gazette', 'location': 'Jeddah, Saudi Arabia', 'url': 'http://www.saudigazette.com.sa', 'description': 'The official Twitter account of Saudi Gazette, a leading English language daily newspaper in Saudi Arabia.', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 142415, 'friends_count': 2, 'listed_count': 1150, 'favourites_count': 7, 'statuses_count': 93701, 'created_at': 'Mon Apr 30 13:01:28 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '333399', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1176623244222353413/Z0TJ_bEy_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1176623244222353413/Z0TJ_bEy_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/567289542/1569690018',  ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @andreasharsono: Indonesia's Ministry of Health's main lab to test #coronavirus infection announced that it is taking an Idul Fitri holi
# {'created_at': 'Sat May 16 14:22:20 +0000 2020', 'id': 1261663275994902528, 'id_str': '1261663275994902528', 'text': "RT @andreasharsono: Indonesia's Ministry of Health's main lab to test #coronavirus infection announced that it is taking an Idul Fitri holi…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1092066941299130368, 'id_str': '1092066941299130368', 'name': 'Satria Baja Hitam', 'screen_name': 'yudhagempa', 'location': None, 'url': None, 'description': 'Jalan dulu baru duduk', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 46, 'friends_count': 92, 'listed_count': 0, 'favourites_count': 3, 'statuses_count': 158, 'created_at': 'Sun Feb 03 14:27:03 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1235682665149292545/2LvFCWte_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235682665149292545/2LvFCWte_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1092066941299130368/1583444680', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat May 16 10:25:47 +0000 2020', 'id': 1261603747999789059, 'id_str': '1261603747999789059', 'text': "Indonesia's Ministry of Health's main lab to test #coronavirus infection announced that it is taking an Idul Fitri… https://t.co/7ZDIGVAPHw", 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 25250613, 'id_str': '25250613', 'name': 'Andreas Harsono', 'screen_name': 'andreasharsono', 'location': 'Indonesia', 'url': None, 'description': 'Human Rights Watch, religious freedom, media and journalism, ethnic and religious violence, human rights  🇮🇩', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 40359, 'friends_count': 3004, 'listed_count': 437, 'favourites_count': 33952, 'statuses_count': 68302, 'created_at': 'Thu Mar 19 06:28:39 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': False, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'A8C7F7', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1238634809733210113/jxCFFe-a_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1238634809733210113/jxCFFe-a_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25250613/1570496553', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @QBlueSkyQ: Sec Azar of HHS w/Gates, W.H.O. Chief Tedros
# Azar was President of Eli Lilly, a major drug company,&amp; a member of the board o
# {'created_at': 'Sat May 16 14:22:20 +0000 2020', 'id': 1261663276271669251, 'id_str': '1261663276271669251', 'text': 'RT @QBlueSkyQ: Sec Azar of HHS w/Gates, W.H.O. Chief Tedros\nAzar was President of Eli Lilly, a major drug company,&amp; a member of the board o…', 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 764859101838848000, 'id_str': '764859101838848000', 'name': 'Dianne Roncelli #GreatAwakening WWG1WGA', 'screen_name': 'DianneRoncelli', 'location': 'California', 'url': None, 'description': '#QAnon', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 4410, 'friends_count': 4999, 'listed_count': 1, 'favourites_count': 45206, 'statuses_count': 135099, 'created_at': 'Sun Aug 14 16:19:55 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Apr 13 14:28:46 +0000 2020', 'id': 1249706096849190913, 'id_str': '1249706096849190913', 'text': 'Sec Azar of HHS w/Gates, W.H.O. Chief Tedros\nAzar was President of Eli Lilly, a major drug company,&amp; a member of th… https://t.co/fRFJfXKdZB', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': 1249441593062502401, 'in_reply_to_status_id_str': '1249441593062502401', 'in_reply_to_user_id': 957234158111215616, 'in_reply_to_user_id_str': '957234158111215616', 'in_reply_to_screen_name': 'QBlueSkyQ', 'user': {'id': 957234158111215616, 'id_str': '957234158111215616', 'name': 'BlueSky⭐️⭐️⭐️', 'screen_name': 'QBlueSkyQ', 'location': None, 'url': 'https://www.youtube.com/watch?v=rxlTl15zmtw&t=136s', 'description': 'Researcher IT Consultant/Software Engineer-Exposing Crimes Against Humanity\nStudy:Babylon/RomanEmpire/Egypt/Bloodlines\nFB @GenFlynn @SidneyPowell1', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 73681, 'friends_count': 22706, 'listed_count': 318, 'favourites_count': 92819, 'statuses_count': 29349, 'created_at': 'Sat Jan 27 12:49:42 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1098927629657354240/YmF0JKwj_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1098927629657354240/YmF0JKwj_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/957234158111215616/1549378093', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notificatio ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at Oops! looks like Boris has jumped the gun again.  Another 468 positively tested deaths yesteday from #coronavirus m https://t.co/mJXW3ARILG
# {'created_at': 'Sat May 16 14:22:20 +0000 2020', 'id': 1261663277127544833, 'id_str': '1261663277127544833', 'text': 'Oops! looks like Boris has jumped the gun again.  Another 468 positively tested deaths yesteday from #coronavirus m… https://t.co/mJXW3ARILG', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 794249524369879040, 'id_str': '794249524369879040', 'name': 'bruce macfarlane', 'screen_name': 'beajayemac', 'location': 'Britain', 'url': 'http://www.timetraveldiaries.co.uk', 'description': 'Retired Health Physicist. Space Time Traveller,  Rambler,  bad jazz guitar player and anything on King Arthur. Angry losing my EU citizenship', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 995, 'friends_count': 325, 'listed_count': 20, 'favourites_count': 13432, 'statuses_count': 18232, 'created_at': 'Thu Nov 03 18:46:57 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/794261767522230273/FtJ5x797_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/794261767522230273/FtJ5x797_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/794249524369879040/1579278033', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Oops! looks like Boris has jumped the gun again.  Another 468 positively tested deaths yesteday from #coronavirus making 34,466 deaths which is nearly up to the total reported by ONS and Scotland up to 1 May. https://t.co/vGXTaSLiVI', 'display_text_range': [0, 208], 'entities': {'hashtags': [{'text': 'coronavirus', 'indices': [101, 113]}], 'urls': [], 'user_mentions': [], 'symbols': [], 'media': [{'id': 1261662725064863745, 'id_str': '1261662725064863745', 'indices': [209, 232], 'media_url': 'http://pbs.twimg.com/media/EYJTkFnXsAE-e7c.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EYJTkFnXsAE-e7c.jpg', 'url': 'https://t.co/vGXTaSLiVI', 'display_url': 'pic.twitter.com/vGXTaSLiVI', 'expanded_url': 'https://twitter.com/beajayemac/status/1261663277127544833/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 778, 'h': 548, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 479, 'resize': 'fit'}, 'medium': {'w': 778, 'h': 548, 'resize': 'fit'}}}, {'id': 1261663201462300672, 'id_str': '1261663201462300672', 'indices': [209, 232], 'media_url': 'http://pbs.twimg.com/media/EYJT_0VXsAATFEa.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EYJT_0VXsAATFEa.jpg', 'url': 'https://t.co/vGXTaSLiVI', 'display_url': 'pic.twitter.com/vGXTaSLiVI', 'expanded_url': 'https://twitter.com/beajayemac/status/1261663277127544833/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 448, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 792, 'h': 522, 'resize': 'fit'}, 'medium': {'w': 792, 'h': 522, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1261662725064863745, 'id_str': '1261662725064863745', 'indices': [209, 232], 'media_url': 'http://pbs.twimg.com/media/EYJTkFnXsAE-e7c.jpg', 'media_url_https': 'https://pbs.twimg.com/media/ ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @1917paul: "for the 1.8 billion people around the world living in #homelessness and inadequate shelter, an appeal to stay home as an a
# {'created_at': 'Sat May 16 14:22:21 +0000 2020', 'id': 1261663280025788416, 'id_str': '1261663280025788416', 'text': 'RT @1917paul: "for the 1.8 billion people around the world living in #homelessness and inadequate shelter, an appeal to “stay home” as an a…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1162363246579453953, 'id_str': '1162363246579453953', 'name': 'Kay #Iamtheunion Ballard', 'screen_name': 'KayBall77922912', 'location': 'The world', 'url': None, 'description': 'Need to know basis,still a threat to Parcelforce management 😒😂\nreluctantly succumbed to twitter', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 199, 'friends_count': 208, 'listed_count': 0, 'favourites_count': 4581, 'statuses_count': 32703, 'created_at': 'Fri Aug 16 14:00:07 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1162363809174097920/MoikZo6U_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1162363809174097920/MoikZo6U_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat May 16 13:51:44 +0000 2020', 'id': 1261655576955797506, 'id_str': '1261655576955797506', 'text': '"for the 1.8 billion people around the world living in #homelessness and inadequate shelter, an appeal to “stay hom… https://t.co/JRjj6uHpUv', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 254578957, 'id_str': '254578957', 'name': 'Paul Kershaw', 'screen_name': '1917paul', 'location': None, 'url': None, 'description': 'Socialist, trade unionist, Chair of Unite LE1111 Housing Workers Branch http://www.housingworkers.org.uk', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2916, 'friends_count': 2915, 'listed_count': 78, 'favourites_count': 15029, 'statuses_count': 19353, 'created_at': 'Sat Feb 19 15:27:37 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1047182584290193409/DRfQFfPW_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1047182584290193409/DRfQFfPW_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/254578957/1588119806', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @Paola_Dec1231: The stunning level of stupidity consistently coming out of Trudeau's fan-club is far more dangerous to Canada's health,
# {'created_at': 'Sat May 16 14:22:21 +0000 2020', 'id': 1261663282944815108, 'id_str': '1261663282944815108', 'text': "RT @Paola_Dec1231: The stunning level of stupidity consistently coming out of Trudeau's fan-club is far more dangerous to Canada's health,…", 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 871979430, 'id_str': '871979430', 'name': 'LJ', 'screen_name': 'Ljtcu', 'location': None, 'url': None, 'description': 'Air traffic controller', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 788, 'friends_count': 406, 'listed_count': 7, 'favourites_count': 165450, 'statuses_count': 97526, 'created_at': 'Wed Oct 10 15:22:32 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/810251260020555778/2GfXiGrY_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/810251260020555778/2GfXiGrY_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat May 16 13:59:55 +0000 2020', 'id': 1261657635616706560, 'id_str': '1261657635616706560', 'text': "The stunning level of stupidity consistently coming out of Trudeau's fan-club is far more dangerous to Canada's hea… https://t.co/ky4pTYiKUz", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1016220361, 'id_str': '1016220361', 'name': 'Queen Paola 🇨🇦 🇮🇹 🇩🇪', 'screen_name': 'Paola_Dec1231', 'location': 'Mississauga, Ontario, Canada', 'url': None, 'description': "I want commonsense governments with leaders who are grateful to serve and respect the people that elected them. Let's put adults back in Ottawa! #TrudeauMustGo", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 15692, 'friends_count': 1238, 'listed_count': 34, 'favourites_count': 98492, 'statuses_count': 8478, 'created_at': 'Sun Dec 16 22:30:19 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1193541714520264711/rYBhuQ9M_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1193541714520264711/rYBhuQ9M_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1016220361/1581777530', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifi ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @AndyOstroy: @realDonaldTrump Ladies and gentlemen...I present the president of the United States...the Sociopath-in-Chief who's egging
# {'created_at': 'Sat May 16 14:22:22 +0000 2020', 'id': 1261663284211507202, 'id_str': '1261663284211507202', 'text': "RT @AndyOstroy: @realDonaldTrump Ladies and gentlemen...I present the president of the United States...the Sociopath-in-Chief who's egging…", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1131665944357421056, 'id_str': '1131665944357421056', 'name': 'SamButch', 'screen_name': 'SamButch4', 'location': None, 'url': None, 'description': 'Executive Assistant, Mom, Grandma', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 0, 'friends_count': 123, 'listed_count': 0, 'favourites_count': 1598, 'statuses_count': 910, 'created_at': 'Thu May 23 20:59:21 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat May 16 01:41:03 +0000 2020', 'id': 1261471692418736128, 'id_str': '1261471692418736128', 'text': "@realDonaldTrump Ladies and gentlemen...I present the president of the United States...the Sociopath-in-Chief who's… https://t.co/nAR21na76E", 'display_text_range': [17, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': 1261470041221902338, 'in_reply_to_status_id_str': '1261470041221902338', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 123281100, 'id_str': '123281100', 'name': 'Andy Ostroy', 'screen_name': 'AndyOstroy', 'location': 'NYC', 'url': 'https://medium.com/@abostroy', 'description': 'Proud democrat. Patriot. Love my country. Writer. Filmmaker/producer. Non-profit founder supporting female filmmakers. Drummer. Candy man. https://t.co/ZxB2nKQnUm', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 75176, 'friends_count': 3074, 'listed_count': 530, 'favourites_count': 44671, 'statuses_count': 40785, 'created_at': 'Mon Mar 15 15:46:27 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'ACDED6', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '110485', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1202747526786535424/jKQCfRdz_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1202747526786535424/jKQCfRdz_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/123281100/1400521645', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': No ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at Now #government trying to do normal the situation through giving more reliefs in #lockdown4  when the situation of https://t.co/Cb9QZoJZrL
# ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at Watch the video please
#
# https://t.co/m17RRk2IX1
#
# #Haaland #Covid_19 #fortnite #dortmund #COVID19 #gaming #gamer https://t.co/v0YHq8S1FH
# {'created_at': 'Sat May 16 14:22:26 +0000 2020', 'id': 1261663300703657984, 'id_str': '1261663300703657984', 'text': 'Watch the video please\n\nhttps://t.co/m17RRk2IX1\n\n#Haaland #Covid_19 #fortnite #dortmund #COVIDー19 #gaming #gamer… https://t.co/v0YHq8S1FH', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1255499427176906758, 'id_str': '1255499427176906758', 'name': 'La Casa Psiquiatrica', 'screen_name': 'LPsiquiatrica', 'location': None, 'url': None, 'description': 'hola soy un intento de youtuber XD', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3, 'friends_count': 65, 'listed_count': 0, 'favourites_count': 4, 'statuses_count': 38, 'created_at': 'Wed Apr 29 14:09:38 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Watch the video please\n\nhttps://t.co/m17RRk2IX1\n\n#Haaland #Covid_19 #fortnite #dortmund #COVIDー19 #gaming #gamer #minecraft #YouTube #URGENTE #Influencer #coronavirus #Bundesliga #StayHome #world', 'display_text_range': [0, 195], 'entities': {'hashtags': [{'text': 'Haaland', 'indices': [49, 57]}, {'text': 'Covid_19', 'indices': [58, 67]}, {'text': 'fortnite', 'indices': [68, 77]}, {'text': 'dortmund', 'indices': [78, 87]}, {'text': 'COVIDー19', 'indices': [88, 97]}, {'text': 'gaming', 'indices': [98, 105]}, {'text': 'gamer', 'indices': [106, 112]}, {'text': 'minecraft', 'indices': [113, 123]}, {'text': 'YouTube', 'indices': [124, 132]}, {'text': 'URGENTE', 'indices': [133, 141]}, {'text': 'Influencer', 'indices': [142, 153]}, {'text': 'coronavirus', 'indices': [154, 166]}, {'text': 'Bundesliga', 'indices': [167, 178]}, {'text': 'StayHome', 'indices': [179, 188]}, {'text': 'world', 'indices': [189, 195]}], 'urls': [{'url': 'https://t.co/m17RRk2IX1', 'expanded_url': 'https://www.youtube.com/watch?v=gUgQlTJ_QRw&feature=share', 'display_url': 'youtube.com/watch?v=gUgQlT…', 'indices': [24, 47]}], 'user_mentions': [], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'Haaland', 'indices': [49, 57]}, {'text': 'Covid_19', 'indices': [58, 67]}, {'text': 'fortnite', 'indices': [68, 77]}, {'text': 'dortmund', 'indices': [78, 87]}, {'text': 'COVIDー19', 'indices': [88, 97]}, {'text': 'gaming', 'indices': [98, 105]}, {'text': 'gamer', 'indices': [106, 112]}], 'urls': [{'url': 'https://t.co/m17RRk2IX1', 'expanded_url': 'https://www.youtube.com/watch?v=gUgQlTJ_QRw&feature=share', 'display_url': 'youtube.com/watch?v=gUgQlT…', 'indices': [24, 47]}, {'url': 'https://t.co/v0YHq8S1FH', 'expanded_url': 'https://twitter.com/i/web/status/1261663300703657984', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [114, 137]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '158963894 ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @DineshDSouza: Dr. Birx admitted they OVERCOUNT #Coronavirus deaths at the federal level, evidently to match the bogus early projections
# {'created_at': 'Sat May 16 14:22:26 +0000 2020', 'id': 1261663301026689025, 'id_str': '1261663301026689025', 'text': 'RT @DineshDSouza: Dr. Birx admitted they OVERCOUNT #Coronavirus deaths at the federal level, evidently to match the bogus early projections…', 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2618121452, 'id_str': '2618121452', 'name': 'Renee', 'screen_name': 'Er360Pry', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 146, 'friends_count': 170, 'listed_count': 0, 'favourites_count': 32734, 'statuses_count': 27776, 'created_at': 'Fri Jul 11 19:30:36 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/617714565451657221/g58z4yWS_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/617714565451657221/g58z4yWS_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri May 15 21:45:30 +0000 2020', 'id': 1261412417579282433, 'id_str': '1261412417579282433', 'text': 'Dr. Birx admitted they OVERCOUNT #Coronavirus deaths at the federal level, evidently to match the bogus early proje… https://t.co/iEAVoyNAM9', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 91882544, 'id_str': '91882544', 'name': "Dinesh D'Souza", 'screen_name': 'DineshDSouza', 'location': 'United States', 'url': 'http://dineshdsouza.com/socialism', 'description': 'Who is behind modern-day socialism, why is it evil, and how can we stop it? "United States of Socialism" is available for pre-order today!', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 1514344, 'friends_count': 5829, 'listed_count': 5984, 'favourites_count': 649, 'statuses_count': 51196, 'created_at': 'Sun Nov 22 22:32:41 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '252929', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_tile': False, 'profile_link_color': '000000', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDFFCC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/890967538292711424/8puyFbiI_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/890967538292711424/8puyFbiI_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/91882544/1581557327', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-1778e64f019e> in <module>
#       1 MyListener = MyListener(api=tweepy.API(wait_on_rate_limit=True))
#       2 myStream = tweepy.Stream(auth = api.auth, listener = MyListener )
# ----> 3 myStream.filter(languages=["en"], track = ['#coronavirus'])
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /Applications/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# /Applications/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
