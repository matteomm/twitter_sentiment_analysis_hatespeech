# %%
from __future__ import print_function
import pandas as pd
import matplotlib.pyplot as plt 
import datetime  
from nltk.tokenize import word_tokenize  
import seaborn as sns
import scipy.stats as stats
from scipy.stats import ttest_ind
import numpy as np
import re
import mysql.connector

import matplotlib.pyplot as plt
from nltk.tokenize import TweetTokenizer

import tweepy
# importing relevant packages to receive Twitter streams
from tweepy import Stream
from tweepy.streaming import StreamListener
# credentials taken from the twitter API
import credentials
import json

from dateutil import parser

# %%
# importing relevant packages to receive Twitter streams
from tweepy import Stream
from tweepy.streaming import StreamListener
# credentials taken from the twitter API
import credentials

# %%
# credentials to access Twitter API
auth  = tweepy.OAuthHandler(credentials.API_KEY, \
                            credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN,  \
                      credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
# create function to strip emojis from the stream
def removeEmoj(text):
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
# create a function to store data in a MYSQL database
def store_data(id_str , created_at, text, processed):
    db=mysql.connector.connect(host="localhost", user="root", passwd="password", db="twitter_2", charset="utf8")
    cursor = db.cursor()
    insert_query = "INSERT INTO twitter_2 (id_str, created_at, text, processed) VALUES (%s, %s, %s, %s)"
    cursor.execute(insert_query, (id_str , created_at, text,processed))
    db.commit()
    cursor.close()
    db.close()
    return

# %%
# connecting the MYSQL database
db = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="password",
    database="twitter_2",
    charset = 'utf8'
)

# %%
# check that it's connected
mycursor = db.cursor()
mycursor.execute("SHOW TABLES")

for x in mycursor:
    print(x)
# Out:
# ('twitter_2',)

# %%
# customising the stream listener to add extra conditions
class MyListener(StreamListener):
 

            
            
            
    def on_data(self, data):
        
        try:
           # Decode the JSON from Twitter
            datajson = json.loads(data)
    
            
             
            
                
            #grab the wanted data from the Tweet
            id_str = datajson['id_str']
            print(1)
            created_at =parser.parse(datajson['created_at'])
#             created_at = datajson['created_at']
            print(2)
            text = datajson['text']
            text = removeEmoj(text)
            
            print(3)
#             user_created_at = parser.parse(datajson['user_created_at']) 
            processed = -1
            print(4)
#             user_location = datajson['user_location']
            
            print(5)

   

            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(text))
            
            #insert the data into the MySQL database
            store_data(id_str , created_at, text, processed)
            print(datajson)
        
        except Exception as e:
            print(e)

# %%
MyListener = MyListener(api=tweepy.API(wait_on_rate_limit=True))
myStream = tweepy.Stream(auth = api.auth, listener = MyListener )
myStream.filter(languages=["en"], track = ['#coronavirus'])
# Out:
# 1
# 2
# 3
# 4
# 5
# Tweet collected at Even IF it worked, the #Coronavirus app was created for Morrison to make a big announcement and take credit for suc https://t.co/DiD9rNGF1t
# {'created_at': 'Tue May 19 22:35:34 +0000 2020', 'id': 1262874567913037824, 'id_str': '1262874567913037824', 'text': 'Even IF it worked, the #Coronavirus app was created for Morrison to make a big announcement and take credit for suc… https://t.co/DiD9rNGF1t', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 838594029797269504, 'id_str': '838594029797269504', 'name': 'Aaron White', 'screen_name': 'AaronKinKin1', 'location': 'Kin Kin QLD Australia', 'url': None, 'description': 'Environmental campaigner, submission writer and integrity activist (between periods of utter disillusionment and despair at the state of politics)', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 209, 'friends_count': 558, 'listed_count': 4, 'favourites_count': 2053, 'statuses_count': 819, 'created_at': 'Mon Mar 06 03:36:11 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1257721682715750400/KLcaOvSt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1257721682715750400/KLcaOvSt_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1262756207552430083, 'quoted_status_id_str': '1262756207552430083', 'quoted_status': {'created_at': 'Tue May 19 14:45:15 +0000 2020', 'id': 1262756207552430083, 'id_str': '1262756207552430083', 'text': "confused why you'd be struggling? I got shat on left right and centre for pointing out a government track record of… https://t.co/k4qQ9gf6MC", 'display_text_range': [0, 140], 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 60796864, 'id_str': '60796864', 'name': 'Nicola is', 'screen_name': 'peacenicsta', 'location': 'Fremantle/Whadjuk noongar land', 'url': 'http://www.patreon.com/nicolaparis', 'description': 'Coordinator @CounterActOz facilitating/training for nonviolent direct action, campaigning, community organising & mischief. Feminist. love trees,sea & red dirt.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3221, 'friends_count': 2754, 'listed_count': 88, 'favourites_count': 8184, 'statuses_count': 35383, 'created_at': 'Tue Jul 28 03:23:27 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FFF04D', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_tile': False, 'profile_link_color': '0099CC', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F6F6F6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/979260191152590848/0hvfUz_D_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/979260191152590848/0hvf ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @Augustlols21: Due to #COVID19 aka #Coronavirus Ill be sending the first 700 people to like &amp; retweet this $300 -$1500 through CashApp,
# {'created_at': 'Tue May 19 22:35:34 +0000 2020', 'id': 1262874568621871104, 'id_str': '1262874568621871104', 'text': 'RT @Augustlols21: Due to #COVID19 aka #Coronavirus Ill be sending the first 700 people to like &amp; retweet this $300 -$1500 through CashApp,…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 872523062867918848, 'id_str': '872523062867918848', 'name': 'Jaquan', 'screen_name': 'Jaquanshell', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 18, 'friends_count': 31, 'listed_count': 1, 'favourites_count': 12, 'statuses_count': 25, 'created_at': 'Wed Jun 07 18:38:03 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1188980049220796419/7YmqoJjr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1188980049220796419/7YmqoJjr_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/872523062867918848/1572309909', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon May 18 11:31:39 +0000 2020', 'id': 1262345099155046401, 'id_str': '1262345099155046401', 'text': 'Due to #COVID19 aka #Coronavirus Ill be sending the first 700 people to like &amp; retweet this $300 -$1500 through Cas… https://t.co/fD6tDc9LcT', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1390647481, 'id_str': '1390647481', 'name': 'August 💕', 'screen_name': 'Augustlols21', 'location': 'United States', 'url': None, 'description': 'Aries ♈️ 😘', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 9483, 'friends_count': 397, 'listed_count': 7, 'favourites_count': 46494, 'statuses_count': 85084, 'created_at': 'Mon Apr 29 22:48:13 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'F5ABB5', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1256280231247298560/xDHLh1Ub_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256280231247298560/xDHLh1Ub_normal.jpg', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Due to #COVID19 aka #Coronavirus Ill be sending the first 700 people to like &a ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @AlexandreKrausz: Cambridge University assumes online lectures until the end of 2021 academic year. This should be the standard for the
# {'created_at': 'Tue May 19 22:35:35 +0000 2020', 'id': 1262874569410568194, 'id_str': '1262874569410568194', 'text': 'RT @AlexandreKrausz: Cambridge University assumes online lectures until the end of 2021 academic year. This should be the standard for the…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1216733528899145729, 'id_str': '1216733528899145729', 'name': 'Dr Claudette Ada Kika 🇳🇬', 'screen_name': 'CA_kika01', 'location': 'London, England', 'url': None, 'description': 'Lecturer in Management || Stylish Academic|| Foodie|| Music Enthusiast|| Interested in #edtech and #HigherEd I tweet about other general stuff too || 🇳🇬🇬🇧', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 308, 'friends_count': 335, 'listed_count': 4, 'favourites_count': 12397, 'statuses_count': 2019, 'created_at': 'Mon Jan 13 14:47:48 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1257047116574330880/aBt8RhmJ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1257047116574330880/aBt8RhmJ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1216733528899145729/1578927623', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue May 19 22:19:54 +0000 2020', 'id': 1262870625514913792, 'id_str': '1262870625514913792', 'text': 'Cambridge University assumes online lectures until the end of 2021 academic year. This should be the standard for t… https://t.co/p4q7MKPf6y', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 471516779, 'id_str': '471516779', 'name': 'Alexandre Krauss', 'screen_name': 'AlexandreKrausz', 'location': 'European Union | Brussels', 'url': 'https://www.instagram.com/alexandre.krauss/', 'description': 'Founder @Liberalpt 🇵🇹 | Senior Political Advisor @RenewEurope | Holocaust Descendant | Europeanist 🇪🇺🇺🇸🇨🇦 Atlanticist | Space 🚀\U0001fa90', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 11513, 'friends_count': 1867, 'listed_count': 119, 'favourites_count': 10554, 'statuses_count': 12226, 'created_at': 'Sun Jan 22 23:47:30 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1133087263515136000/CayzFngj_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1133087263515136000/CayzFngj_normal.png', 'profile ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @ThesisPi: That awkward moment when taking prescription drugs without a prescription is like taking Vitamins, and definitely not drug ab
# {'created_at': 'Tue May 19 22:35:35 +0000 2020', 'id': 1262874571000000512, 'id_str': '1262874571000000512', 'text': 'RT @ThesisPi: That awkward moment when taking prescription drugs without a prescription is like taking Vitamins, and definitely not drug ab…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 344941763, 'id_str': '344941763', 'name': '🇨🇦204Girl0574🇨🇦', 'screen_name': '204Girl0574', 'location': 'Winnipeg, Manitoba', 'url': 'http://www.conservativescansuckit.com', 'description': 'Life-long Winnipegger and dedicated Jets and Bombers fan.  Fiercely proud of all things Winnipeg! Registered member of the Liberal Party of Canada. NO DMS!!!', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1727, 'friends_count': 2507, 'listed_count': 14, 'favourites_count': 66740, 'statuses_count': 51774, 'created_at': 'Fri Jul 29 20:40:39 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1170532530770104320/ng1nvcAd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170532530770104320/ng1nvcAd_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/344941763/1554585373', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue May 19 22:13:12 +0000 2020', 'id': 1262868936804020224, 'id_str': '1262868936804020224', 'text': 'That awkward moment when taking prescription drugs without a prescription is like taking Vitamins, and definitely n… https://t.co/1mYcnMY5wY', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 879506869529616384, 'id_str': '879506869529616384', 'name': 'Thesis Pi', 'screen_name': 'ThesisPi', 'location': 'Calgary, Alberta', 'url': None, 'description': 'Advocate for: people with disabilities, mental health, clean energy, LGBTQ, cannabis culture, and democratic inclusion. RT/Follow Not Endorsement', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1433, 'friends_count': 3719, 'listed_count': 7, 'favourites_count': 39358, 'statuses_count': 34968, 'created_at': 'Tue Jun 27 01:09:12 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/952430969406894081/wfcMccwo_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/952430969406894081/wfcMccwo_normal.jpg', 'pro ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected
normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/877699334/1370080451', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': Non ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @mayawiley: I wish instead of descending into a silly news cycle on #Trump body mass as a fact check on #Pelosi, we considered the milli
# {'created_at': 'Tue May 19 22:35:38 +0000 2020', 'id': 1262874583687806977, 'id_str': '1262874583687806977', 'text': 'RT @mayawiley: I wish instead of descending into a silly news cycle on #Trump body mass as a fact check on #Pelosi, we considered the milli…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1623131262, 'id_str': '1623131262', 'name': 'CloverLeaf', 'screen_name': 'jnewtontm', 'location': 'United States', 'url': None, 'description': "Fav Constitutional phrase '...promote the general welfare...' emphasis on 'general'; not mentioned-corporate or oligarch welfare. RT not = endorsement. he/him", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 384, 'friends_count': 2098, 'listed_count': 9, 'favourites_count': 52575, 'statuses_count': 232695, 'created_at': 'Fri Jul 26 15:00:50 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue May 19 20:11:17 +0000 2020', 'id': 1262838255256510476, 'id_str': '1262838255256510476', 'text': 'I wish instead of descending into a silly news cycle on #Trump body mass as a fact check on #Pelosi, we considered… https://t.co/7BSjoDLPh9', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 96675300, 'id_str': '96675300', 'name': 'Maya Wiley', 'screen_name': 'mayawiley', 'location': None, 'url': None, 'description': 'NBC News & @MSNBC Legal Analyst, Univ Prof @TheNewSchool. Views & typos r mine. “Give light and people will find the way” - Ella Baker. Pronouns-She/her', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 303836, 'friends_count': 3525, 'listed_count': 1925, 'favourites_count': 23501, 'statuses_count': 35261, 'created_at': 'Mon Dec 14 02:27:55 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1076260932240711681/E4dkcf0t_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1076260932240711681/E4dkcf0t_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/96675300/15842 ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @UNYouthEnvoy: LGBTQI+ young ppl face many challenges during the #COVID19 pandemic!
#
# Despite this, many LGBTQI+ youth are leading the fi
# {'created_at': 'Tue May 19 22:35:38 +0000 2020', 'id': 1262874584073863168, 'id_str': '1262874584073863168', 'text': 'RT @UNYouthEnvoy: LGBTQI+ young ppl face many challenges during the #COVID19 pandemic!\n\nDespite this, many LGBTQI+ youth are leading the fi…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 903352146489294848, 'id_str': '903352146489294848', 'name': 'Lamek Mageto™', 'screen_name': 'Lamek_Mageto', 'location': 'Kigali', 'url': None, 'description': 'HealthEquityChamp', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 247, 'friends_count': 576, 'listed_count': 0, 'favourites_count': 681, 'statuses_count': 447, 'created_at': 'Thu Aug 31 20:21:50 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1259940864874491904/k1TGoKSN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1259940864874491904/k1TGoKSN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/903352146489294848/1588593415', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon May 18 22:08:44 +0000 2020', 'id': 1262505424558964740, 'id_str': '1262505424558964740', 'text': 'LGBTQI+ young ppl face many challenges during the #COVID19 pandemic!\n\nDespite this, many LGBTQI+ youth are leading… https://t.co/RNZMTWiWef', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2923724679, 'id_str': '2923724679', 'name': 'UN Youth Envoy', 'screen_name': 'UNYouthEnvoy', 'location': None, 'url': 'https://www.un.org/youthenvoy/', 'description': "Official account of the @UN Secretary-General's Envoy on Youth, Ms. Jayathma Wickramanayake - @jayathmadw. Bringing the UN closer to young people. #Youth2030", 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 118245, 'friends_count': 1264, 'listed_count': 631, 'favourites_count': 13283, 'statuses_count': 17449, 'created_at': 'Mon Dec 15 22:20:30 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1146490047866257409/fqhGCnWb_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1146490047866257409/fqhGCnWb_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/
 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 878247600096509952, 'id_str': '878247600096509952', 'name': 'Candace Owens', 'screen_name': 'RealCandaceO', 'location': 'New York, USA', 'url': 'https://www.simonandschuster.com/books/Blackout/Candace-Owens/9781982133276', 'description': 'My book BLACKOUT is available on Amazon, Barnes & Noble, Kindle and more!', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 2226690, 'friends_count': 15, 'listed_count': 5181, 'favourites_count': 19380, 'statuses_count': 3940, 'created_at': 'Fri Jun 23 13:45:19 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1251211363181121537/otlXqNH2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1251211363181121537/otlXqNH2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/878247600096509952/1587147011', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None} ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1778e64f019e> in <module>
#       1 MyListener = MyListener(api=tweepy.API(wait_on_rate_limit=True))
#       2 myStream = tweepy.Stream(auth = api.auth, listener = MyListener )
# ----> 3 myStream.filter(languages=["en"], track = ['#coronavirus'])
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /Applications/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# /Applications/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
