# %%
from __future__ import print_function
import pandas as pd
import matplotlib.pyplot as plt 
import datetime  
from nltk.tokenize import word_tokenize  
import seaborn as sns
import scipy.stats as stats
from scipy.stats import ttest_ind
import numpy as np
import re
import mysql.connector

import matplotlib.pyplot as plt
from nltk.tokenize import TweetTokenizer

import tweepy
# importing relevant packages to receive Twitter streams
from tweepy import Stream
from tweepy.streaming import StreamListener
# credentials taken from the twitter API
import credentials
import json

from dateutil import parser

# %%
# importing relevant packages to receive Twitter streams
from tweepy import Stream
from tweepy.streaming import StreamListener
# credentials taken from the twitter API
import credentials

# %%
# credentials to access Twitter API
auth  = tweepy.OAuthHandler(credentials.API_KEY, \
                            credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN,  \
                      credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
# create function to strip emojis from the stream
def removeEmoj(text):
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
# create a function to store data in a MYSQL database
def store_data(id_str , created_at, text, processed):
    db=mysql.connector.connect(host="localhost", user="root", passwd="password", db="twitter_2", charset="utf8")
    cursor = db.cursor()
    insert_query = "INSERT INTO twitter_2 (id_str, created_at, text, processed) VALUES (%s, %s, %s, %s)"
    cursor.execute(insert_query, (id_str , created_at, text,processed))
    db.commit()
    cursor.close()
    db.close()
    return

# %%
# connecting the MYSQL database
db = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="password",
    database="twitter_2",
    charset = 'utf8'
)

# %%
# check that it's connected
mycursor = db.cursor()
mycursor.execute("SHOW TABLES")

for x in mycursor:
    print(x)
# Out:
# ('twitter_2',)

# %%
# customising the stream listener to add extra conditions
class MyListener(StreamListener):
 

            
            
            
    def on_data(self, data):
        
        try:
           # Decode the JSON from Twitter
            datajson = json.loads(data)
    
            
             
            
                
            #grab the wanted data from the Tweet
            id_str = datajson['id_str']
            print(1)
            created_at =parser.parse(datajson['created_at'])
#             created_at = datajson['created_at']
            print(2)
            text = datajson['text']
            text = removeEmoj(text)
            
            print(3)
#             user_created_at = parser.parse(datajson['user_created_at']) 
            processed = -1
            print(4)
#             user_location = datajson['user_location']
            
            print(5)

   

            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(text))
            
            #insert the data into the MySQL database
            store_data(id_str , created_at, text, processed)
            print(datajson)
        
        except Exception as e:
            print(e)

# %%
MyListener = MyListener(api=tweepy.API(wait_on_rate_limit=True))
myStream = tweepy.Stream(auth = api.auth, listener = MyListener )
myStream.filter(languages=["en"], track = ['#coronavirus'])
# Out:
# 1
# 2
# 3
# 4
# 5
# Tweet collected at Utica Walgreens temporarily closes for cleaning after employee was exposed to coronavirus https://t.co/vhdteP6GsO https://t.co/bFxU9cllAs
# {'created_at': 'Sun May 24 17:38:31 +0000 2020', 'id': 1264611750969737219, 'id_str': '1264611750969737219', 'text': 'Utica Walgreens temporarily closes for cleaning after employee was exposed to coronavirus https://t.co/vhdteP6GsO… https://t.co/bFxU9cllAs', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 
 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 13344, 'friends_count': 727, 'listed_count': 272, 'favourites_count': 70412, 'statuses_count': 39285, 'created_at': 'Thu Sep 18 14:16:09 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'FF2634', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1252591940522082305/VKjbrcMC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252591940522082305/VKjbrcMC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2817144043/1589470179', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'CanadaNews', 'indices': [107, 118]}, {'text': 'COVID19', 'indices': [119, 127]}, {'text': 'Coronavirus', 'indices': [128, 140]}], 'urls': [{'url': 'https://t.co/Ws3RrJCHxI', 'expanded_url': 'http://zpr.io/tVLdz', 'display_url': 'zpr.io/tVLdz', 'indices': [83, 106]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1590341912962'}
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @Kasparov63: Imagine a 9/11 every week and the President saying get used to it, ignore it. Worse, this carnage, 100,000 and counting, wa
# {'created_at': 'Sun May 24 17:38:33 +0000 2020', 'id': 1264611757814923266, 'id_str': '1264611757814923266', 'text': 'RT @Kasparov63: Imagine a 9/11 every week and the President saying get used to it, ignore it. Worse, this carnage, 100,000 and counting, wa…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 15472373, 'id_str': '15472373', 'name': 'Cocacolakid', 'screen_name': 'Cocacolakid', 'location': 'Chicago', 'url': None, 'description': 'Low carb keto aficionado. Caregiver. Defender of Equal Human Rights. #LGBTQ ally. #BlackLivesMatter', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2402, 'friends_count': 1195, 'listed_count': 9, 'favourites_count': 100838, 'statuses_count': 78175, 'created_at': 'Thu Jul 17 19:22:14 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/919625430646132736/22VDK0qv_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/919625430646132736/22VDK0qv_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15472373/1492374529', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun May 24 17:35:03 +0000 2020', 'id': 1264610879745728518, 'id_str': '1264610879745728518', 'text': 'Imagine a 9/11 every week and the President saying get used to it, ignore it. Worse, this carnage, 100,000 and coun… https://t.co/4Ccn1WTS37', 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 449588356, 'id_str': '449588356', 'name': 'Garry Kasparov', 'screen_name': 'Kasparov63', 'location': 'New York', 'url': 'http://kasparov.com', 'description': 'Join RDI! @Renew_Democracy. Chairman of the Human Rights Foundation (@HRF). Author, speaker, 13th World Chess Champion https://www.facebook.com/GKKasparov', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 551445, 'friends_count': 530, 'listed_count': 6435, 'favourites_count': 156, 'statuses_count': 29620, 'created_at': 'Thu Dec 29 08:17:34 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': True, 'profile_link_color': '91D2FA', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1004031810173579265/YrEIbzio_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1004031810173579265/YrEIbzio_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/pro ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @realmayalani: @thejtlewis @realDonaldTrump I am trump2020 supporter
#
# President @realDonaldTrump is donating this quarter's salary to @
# {'created_at': 'Sun May 24 17:38:33 +0000 2020', 'id': 1264611758372794368, 'id_str': '1264611758372794368', 'text': "RT @realmayalani: @thejtlewis @realDonaldTrump I am trump2020 supporter \n\nPresident @realDonaldTrump is donating this quarter's salary to @…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1247228595308806146, 'id_str': '1247228595308806146', 'name': 'Jane', 'screen_name': 'JaneLeeHunz', 'location': None, 'url': None, 'description': 'Patriots.. must stand. \nGod bless... \nno poison vaxx.\nno 🖐g lol', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count':
 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 111, 'friends_count': 234, 'listed_count': 0, 'favourites_count': 1398, 'statuses_count': 2077, 'created_at': 'Wed May 09 20:21:16 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/824198916858060802/Ko1vZzKn_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/824198916858060802/Ko1vZzKn_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/575651347/1554537460', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun May 24 10:31:53 +0000 2020', 'id': 1264504387247972353, 'id_str': '1264504387247972353', 'text': 'Sent to my MP. Please retweet if you can and please write to your local MP too, the louder this voiced the more cha… https://t.co/M2M6RhrUas', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 417777065, 'id_str': '417777065', 'name': 'Calum Rooney', 'screen_name': 'AllYourChickens', 'location': 'Manchester, England', 'url': 'https://www.facebook.com/calum.rooney.7', 'description': "The lights are on but it's not my house.", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 21, 'friends_count': 174, 'listed_count': 0, 'favourites_count': 19, 'statuses_count': 818, 'created_at': 'Mon Nov 21 10:56:38 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': False, 'profile_link_color': 'DD2E44', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1264505627541483521/1t1yVvCa_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1264505627541483521/1t1yVvCa_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/417777065/1445577591', 'default_profile': False, 'default_profile_image': False, 'followin ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @10DowningStreet: THREAD 1/2: #Coronavirus press conference slides (24 May 2020)
#
#  Changes in transport use (Great Britain)
#  Testing a
# {'created_at': 'Sun May 24 17:38:34 +0000 2020', 'id': 1264611765868015616, 'id_str': '1264611765868015616', 'text': 'RT @10DowningStreet: THREAD 1/2: #Coronavirus press conference slides (24 May 2020)\n\n🔵 Changes in transport use (Great Britain)\n🔵 Testing a…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3938536053, 'id_str': '3938536053', 'name': 'Albert Bailey III', 'screen_name': 'Beto10cafetero', 'location': 'Virginia, USA', 'url': 'http://BaileyGroupInt.blogspot.com', 'description': 'Founder/Dir. Bailey Group International LLC, NoVA policy/media consultancy start-up. GMU alum-BA History. @BaileyGrpINT AEBIII.TBG@gmail.com CashApp- $Alby25', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 462, 'friends_count': 5001, 'listed_count': 16, 'favourites_count': 101086, 'statuses_count': 48818, 'created_at': 'Mon Oct 12 16:25:02 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/822120479028903936/cMCx74O5_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822120479028903936/cMCx74O5_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3938536053/1469217992', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun May 24 16:45:35 +0000 2020', 'id': 1264598428304265216, 'id_str': '1264598428304265216', 'text': 'THREAD 1/2: #Coronavirus press conference slides (24 May 2020)\n\n🔵 Changes in transport use (Great Britain)\n🔵 Testin… https://t.co/R3ouYYbluy', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 14224719, 'id_str': '14224719', 'name': 'UK Prime Minister', 'screen_name': '10DowningStreet', 'location': '10 Downing Street, London', 'url': 'http://www.number10.gov.uk', 'description': "Official page for Prime Minister @BorisJohnson's office, based at 10 Downing Street #StayAlert", 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 5787359, 'friends_count': 275, 'listed_count': 22140, 'favourites_count': 1771, 'statuses_count': 14751, 'created_at': 'Wed Mar 26 11:16:02 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '912B89', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'E0FF92', 'profile_text_color': '000000', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1194659082000572416/X2Xo7kAI_normal.png', 'profile_image_url_https': 'https ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @pinkk9lover: Are wrongful deaths suits to follow? Strange... where is the outrage from #Democrats or bellows for an investigation from
# ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected
 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 13664, 'friends_count': 13823, 'listed_count': 7, 'favourites_count': 7034, 'statuses_count': 52497, 'created_at': 'Wed Mar 13 15:27:24 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1252680575904858114/qAk3CN3U_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252680575904858114/qAk3CN3U_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1105852870421815296/1587497298', 'default_profile': True ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1778e64f019e> in <module>
#       1 MyListener = MyListener(api=tweepy.API(wait_on_rate_limit=True))
#       2 myStream = tweepy.Stream(auth = api.auth, listener = MyListener )
# ----> 3 myStream.filter(languages=["en"], track = ['#coronavirus'])
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /Applications/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# /Applications/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
