# %%
from __future__ import print_function
import pandas as pd
import matplotlib.pyplot as plt 
import datetime  
from nltk.tokenize import word_tokenize  
import seaborn as sns
import scipy.stats as stats
from scipy.stats import ttest_ind
import numpy as np
import re
import mysql.connector

import matplotlib.pyplot as plt
from nltk.tokenize import TweetTokenizer

import tweepy
# importing relevant packages to receive Twitter streams
from tweepy import Stream
from tweepy.streaming import StreamListener
# credentials taken from the twitter API
import credentials
import json

from dateutil import parser

# %%
# importing relevant packages to receive Twitter streams
from tweepy import Stream
from tweepy.streaming import StreamListener
# credentials taken from the twitter API
import credentials

# %%
# credentials to access Twitter API
auth  = tweepy.OAuthHandler(credentials.API_KEY, \
                            credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN,  \
                      credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
# create function to strip emojis from the stream
def removeEmoj(text):
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
# create a function to store data in a MYSQL database
def store_data(id_str , created_at, text, processed):
    db=mysql.connector.connect(host="localhost", user="root", passwd="password", db="twitter_2", charset="utf8")
    cursor = db.cursor()
    insert_query = "INSERT INTO twitter_2 (id_str, created_at, text, processed) VALUES (%s, %s, %s, %s)"
    cursor.execute(insert_query, (id_str , created_at, text,processed))
    db.commit()
    cursor.close()
    db.close()
    return

# %%
# connecting the MYSQL database
db = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="password",
    database="twitter_2",
    charset = 'utf8'
)

# %%
# check that it's connected
mycursor = db.cursor()
mycursor.execute("SHOW TABLES")

for x in mycursor:
    print(x)
# Out:
# ('twitter_2',)

# %%
# customising the stream listener to add extra conditions
class MyListener(StreamListener):
 

            
            
            
    def on_data(self, data):
        
        try:
           # Decode the JSON from Twitter
            datajson = json.loads(data)
    
            
             
            
                
            #grab the wanted data from the Tweet
            id_str = datajson['id_str']
            print(1)
            created_at =parser.parse(datajson['created_at'])
#             created_at = datajson['created_at']
            print(2)
            text = datajson['text']
            text = removeEmoj(text)
            
            print(3)
#             user_created_at = parser.parse(datajson['user_created_at']) 
            processed = -1
            print(4)
#             user_location = datajson['user_location']
            
            print(5)

   

            #print out a message to the screen that we have collected a tweet
            print("Tweet collected at " + str(text))
            
            #insert the data into the MySQL database
            store_data(id_str , created_at, text, processed)
            print(datajson)
        
        except Exception as e:
            print(e)

# %%
MyListener = MyListener(api=tweepy.API(wait_on_rate_limit=True))
myStream = tweepy.Stream(auth = api.auth, listener = MyListener )
myStream.filter(languages=["en"], track = ['#coronavirus'])
# Out:
# 1
# 2
# 3
# 4
# 5
# Tweet collected at @PeterObi gives road map to economic recovery post #COVID19 #coronavirus @julietkego @iSERVE2050 @Umu_Igbo https://t.co/mG2uivMcmQ
# {'created_at': 'Mon May 18 09:28:43 +0000 2020', 'id': 1262314163717705728, 'id_str': '1262314163717705728', 'text': '@PeterObi gives road map to economic recovery post #COVID19 #coronavirus @julietkego @iSERVE2050 @Umu_Igbo… https://t.co/mG2uivMcmQ', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 1050779471731707904, 'in_reply_to_user_id_str': '1050779471731707904', 'in_reply_to_screen_name': 'PeterObi', 'user': {'id': 377745504, 'id_str': '377745504', 'name': 'AdlynJohn', 'screen_name': 'AddyJonny1', 'location': 'Nigeria', 'url': None, 'description': 'God-lover, Nigerian patriot, writer, content-creator', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 276, 'friends_count': 755, 'listed_count': 0, 'favourites_count': 2629, 'statuses_count': 2117, 'created_at': 'Thu Sep 22 01:43:02 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'ACDED6', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '91D2FA', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'E3FFFD', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1209087014441762816/thoTwRAK_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1209087014441762816/thoTwRAK_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/377745504/1577104398', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': '@PeterObi gives road map to economic recovery post #COVID19 #coronavirus @julietkego @iSERVE2050 @Umu_Igbo @woodengong @DrJoeAbah \nhttps://t.co/Kx3PecaLnF', 'display_text_range': [0, 154], 'entities': {'hashtags': [{'text': 'COVID19', 'indices': [51, 59]}, {'text': 'coronavirus', 'indices': [60, 72]}], 'urls': [{'url': 'https://t.co/Kx3PecaLnF', 'expanded_url': 'https://www.bbc.com/igbo/52689096', 'display_url': 'bbc.com/igbo/52689096', 'indices': [131, 154]}], 'user_mentions': [{'screen_name': 'PeterObi', 'name': 'Peter Obi', 'id': 1050779471731707904, 'id_str': '1050779471731707904', 'indices': [0, 9]}, {'screen_name': 'julietkego', 'name': "Juliet 'Kego | #Nduka @OnyeAghanaNwanneYa", 'id': 382413245, 'id_str': '382413245', 'indices': [73, 84]}, {'screen_name': 'iSERVE2050', 'name': 'iSERVE 2050 | #LeadershipMatters Nwanyịbùífé🔥#ABC', 'id': 1022592714871906304, 'id_str': '1022592714871906304', 'indices': [85, 96]}, {'screen_name': 'Umu_Igbo', 'name': 'Ụmụ Igbo', 'id': 1060891758, 'id_str': '1060891758', 'indices': [97, 106]}, {'screen_name': 'woodengong', 'name': 'Magna Tata', 'id': 135051958, 'id_str': '135051958', 'indices': [107, 118]}, {'screen_name': 'DrJoeAbah', 'name': 'Dr. Joe Abah', 'id': 2257546388, 'id_str': '2257546388', 'indices': [119, 129]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'COVID19', 'indices': [51, 59]}, {'text': 'coronavirus', 'indices': [60, 72]}], 'urls': [{'url': 'https://t.co/mG2uivMcmQ', 'expanded_url': 'https://twitter.com/i/web/status/1262314163717705728', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [108, 131]}], 'user_mentions': [{'screen_name': 'PeterObi', 'name': 'Peter Obi', 'id': 1050779471731707904, 'id_str': '1050779471731707904', 'indices': [0, 9]}, {'screen_name': 'julietkego', 'name': "Juliet 'Kego | #Nduka @On ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @SheenaParish: WHO offered me 20million dollars to put a little toxic in my Covid-19 remedy  Madagascar President exposes WHO  Obrem
# {'created_at': 'Mon May 18 09:28:44 +0000 2020', 'id': 1262314166422958081, 'id_str': '1262314166422958081', 'text': 'RT @SheenaParish: “WHO offered me 20million dollars to put a little toxic in my Covid-19 remedy” – Madagascar President exposes WHO – Obrem…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1246531669869228032, 'id_str': '1246531669869228032', 'name': 'Kindred_spirit44', 'screen_name': 'KSpirit44', 'location': 'Calgary, Alberta', 'url': None, 'description': '#WWG1WGA 🇨🇦', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 152, 'friends_count': 291, 'listed_count': 3, 'favourites_count': 6364, 'statuses_count': 255, 'created_at': 'Sat Apr 04 20:14:54 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1250094670278873088/DJe80m5u_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250094670278873088/DJe80m5u_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun May 17 05:55:42 +0000 2020', 'id': 1261898168150700033, 'id_str': '1261898168150700033', 'text': '“WHO offered me 20million dollars to put a little toxic in my Covid-19 remedy” – Madagascar President exposes WHO –… https://t.co/bec7ItuwTC', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 564725304, 'id_str': '564725304', 'name': 'Sheena Parish', 'screen_name': 'SheenaParish', 'location': None, 'url': None, 'description': "https://www.youtube.com/watch?v=KrYl76Yx6BY&feature=youtu.be Capitalism without socialism=Fascism. Socialism without capitalism=Communism.\nIt's That Simple!", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2681, 'friends_count': 2158, 'listed_count': 112, 'favourites_count': 21897, 'statuses_count': 134597, 'created_at': 'Fri Apr 27 14:13:25 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3718282286/ce6feae6cc6c7e3666e67fe192214594_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3718282286/ce6feae6cc6c7e3666e67fe192214594_normal.jpeg', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text' ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at Do we know if this is true? I hope so! #LockHimUp #BillGatesIsEvil
# {'created_at': 'Mon May 18 09:28:44 +0000 2020', 'id': 1262314166423031809, 'id_str': '1262314166423031809', 'text': 'Do we know if this is true? I hope so! #LockHimUp #BillGatesIsEvil', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1238449541013295104, 'id_str': '1238449541013295104', 'name': '@ubs.😊nd🇺🇸🇺🇸', 'screen_name': 'and_aubs', 'location': 'North Carolina, USA', 'url': None, 'description': '#Q #QAnon #WWG1WGA #MAGA #KAGA🇺🇸 #DRAINTHESWAMP #patriot #inittogether #godwins', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 169, 'friends_count': 292, 'listed_count': 0, 'favourites_count': 463, 'statuses_count': 212, 'created_at': 'Fri Mar 13 12:59:27 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1238449738560802818/wXpVKGXx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1238449738560802818/wXpVKGXx_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1262181108248129536, 'quoted_status_id_str': '1262181108248129536', 'quoted_status': {'created_at': 'Mon May 18 00:40:01 +0000 2020', 'id': 1262181108248129536, 'id_str': '1262181108248129536', 'text': 'FDA halts the #coronavirus testing program because #Gates is under house arrest, awaiting trial. https://t.co/Dbi5l95Cql', 'display_text_range': [0, 96], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1663191192, 'id_str': '1663191192', 'name': 'Utsava-ACCURATE #Trump #prophecies-#WWG1WGA', 'screen_name': 'Utsava4', 'location': 'United States', 'url': 'http://www.utsava.net', 'description': 'UTSAVA PSYCHIC MEDIUM, DEMOCRACY LESSON # 1, Join me on https://t.co/6VmXfZBqGr, book a reading: visit  https://t.co/gBslULJoAN #Trump2020 #JFKjr #MAGA #2020', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 19965, 'friends_count': 283, 'listed_count': 57, 'favourites_count': 9392, 'statuses_count': 15436, 'created_at': 'Sun Aug 11 18:54:35 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'F58EA8', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1211369917716553728/FhUWwfOQ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211369917716553728/FhUWwfOQ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1663191192/1546166817', 'default_profile': False, 'default_profile_image': False, 'following':  ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @JEPaquetEU: The EU is organizing a global pledging event to help finance a #coronavirus vaccine. We aim to raise 7.5 billion in init
# {'created_at': 'Mon May 18 09:28:46 +0000 2020', 'id': 1262314173700112387, 'id_str': '1262314173700112387', 'text': 'RT @JEPaquetEU: The 🇪🇺EU is organizing a global pledging event to help finance a #coronavirus vaccine. We aim to raise €7.5 billion in init…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 942382320513896448, 'id_str': '942382320513896448', 'name': 'GOEASY', 'screen_name': 'GOEASYproject', 'location': None, 'url': 'https://goeasyproject.eu/', 'description': 'Delivering innovative services and enablers for industry and smart cities\n--\nSupported by EU H2020 research and innovation programme, grant agreement No 776261.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 64, 'friends_count': 62, 'listed_count': 0, 'favourites_count': 620, 'statuses_count': 136, 'created_at': 'Sun Dec 17 13:13:48 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/942695685345939457/Q9KM90ep_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942695685345939457/Q9KM90ep_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/942382320513896448/1513591119', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Apr 27 08:57:54 +0000 2020', 'id': 1254696260810035203, 'id_str': '1254696260810035203', 'text': 'The 🇪🇺EU is organizing a global pledging event to help finance a #coronavirus vaccine. We aim to raise €7.5 billion… https://t.co/PtlSO36Y8c', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 699257234308599808, 'id_str': '699257234308599808', 'name': 'Jean-Eric Paquet', 'screen_name': 'JEPaquetEU', 'location': 'Brussels, Belgium', 'url': 'https://ec.europa.eu/info/research-and-innovation_en', 'description': 'Director-General for #Research & #Innovation @EUScienceInnov @EU_Commission 🇪🇺 Account managed by my team & me. Personal posts signed JEP #HorizonEU #RiDaysEU', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 9030, 'friends_count': 1132, 'listed_count': 114, 'favourites_count': 2412, 'statuses_count': 1872, 'created_at': 'Mon Feb 15 15:41:31 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1005115802595594241/tXJcsdLk_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1005115802595594241/tXJcsdLk_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banne ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan
# {'created_at': 'Mon May 18 09:28:46 +0000 2020', 'id': 1262314176019599363, 'id_str': '1262314176019599363', 'text': 'RT @RealJamesWoods: #KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering thousan…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2212207996, 'id_str': '2212207996', 'name': 'Paul Sudol', 'screen_name': 'sudol_paul', 'location': 'Richmond, VA', 'url': None, 'description': 'Student CoG - Father - VDOT Bridges - Log Home - Harley-Davidson V-Rod - Lehigh University - Nether Providence - Rebuilding - DIY - Golf - MLB - Squirrels', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 39, 'friends_count': 163, 'listed_count': 1, 'favourites_count': 5046, 'statuses_count': 553, 'created_at': 'Sat Dec 07 13:33:21 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/433745055505858560/MlEIH39x_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/433745055505858560/MlEIH39x_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2212207996/1398387968', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun May 17 21:07:15 +0000 2020', 'id': 1262127565419868160, 'id_str': '1262127565419868160', 'text': '#KillerCuomo and other Democrat vermin shoehorn infected #CoronaVirus carriers into nursing homes, slaughtering tho… https://t.co/ciS2IlKk43', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 78523300, 'id_str': '78523300', 'name': 'James Woods', 'screen_name': 'RealJamesWoods', 'location': None, 'url': None, 'description': 'This is the ONLY verified Twitter account for James Woods. All others are fake. “Ballot harvesting” is voter fraud. Say no to indiscriminate “mail-in” voting.', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 2374441, 'friends_count': 5144, 'listed_count': 8381, 'favourites_count': 9761, 'statuses_count': 30562, 'created_at': 'Wed Sep 30 05:31:28 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/796482667340382211/CoV8077b_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/796482667340382211/CoV8077b_normal.jpg ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at @RedwingUK1978 @piersmorgan  #coronavirus isn't political, it's a global pandemic that needs a united world to sol https://t.co/38wuahJ2Jb
# {'created_at': 'Mon May 18 09:28:46 +0000 2020', 'id': 1262314176325746689, 'id_str': '1262314176325746689', 'text': "@RedwingUK1978 @piersmorgan 👍 #coronavirus isn't political, it's a global pandemic that needs a united world to sol… https://t.co/38wuahJ2Jb", 'display_text_range': [28, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': 1262307718762844162, 'in_reply_to_status_id_str': '1262307718762844162', 'in_reply_to_user_id': 1012829071, 'in_reply_to_user_id_str': '1012829071', 'in_reply_to_screen_name': 'RedwingUK1978', 'user': {'id': 235551642, 'id_str': '235551642', 'name': 'Dave⭐️⭐️', 'screen_name': 'dj_zotov', 'location': 'Nottingham', 'url': None, 'description': 'Positive Nottm Forest fan, Notts CCC and England cricket fan and keen amateur  photographer http://www.djzphotos.co.uk', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1690, 'friends_count': 2157, 'listed_count': 39, 'favourites_count': 88232, 'statuses_count': 39254, 'created_at': 'Sat Jan 08 13:51:31 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1251909508823203842/J_MwGgUA_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1251909508823203842/J_MwGgUA_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/235551642/1532387083', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': "@RedwingUK1978 @piersmorgan 👍 #coronavirus isn't political, it's a global pandemic that needs a united world to solve.\nBlame, like a too late #lockdownuk can come later when we are all safe.", 'display_text_range': [28, 190], 'entities': {'hashtags': [{'text': 'coronavirus', 'indices': [30, 42]}, {'text': 'lockdownuk', 'indices': [142, 153]}], 'urls': [], 'user_mentions': [{'screen_name': 'RedwingUK1978', 'name': '🇬🇧 Ian 🇬🇧', 'id': 1012829071, 'id_str': '1012829071', 'indices': [0, 14]}, {'screen_name': 'piersmorgan', 'name': 'Piers Morgan', 'id': 216299334, 'id_str': '216299334', 'indices': [15, 27]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'coronavirus', 'indices': [30, 42]}], 'urls': [{'url': 'https://t.co/38wuahJ2Jb', 'expanded_url': 'https://twitter.com/i/web/status/1262314176325746689', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [{'screen_name': 'RedwingUK1978', 'name': '🇬🇧 Ian 🇬🇧', 'id': 1012829071, 'id_str': '1012829071', 'indices': [0, 14]}, {'screen_name': 'piersmorgan', 'name': 'Piers Morgan', 'id': 216299334, 'id_str': '216299334', 'indices': [15, 27]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1589794126956'}
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @21WIRE: You can see how deep the #BillGates/#Fauci agenda has penetrated the states now. Here's one dissenting voice from #Minnesota...
# {'created_at': 'Mon May 18 09:28:46 +0000 2020', 'id': 1262314176418062338, 'id_str': '1262314176418062338', 'text': "RT @21WIRE: You can see how deep the #BillGates/#Fauci agenda has penetrated the states now. Here's one dissenting voice from #Minnesota...…", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 256933322, 'id_str': '256933322', 'name': 'JosephKattab יוסף يوسف خطاب\U0001f9be', 'screen_name': 'joekattab_Oil', 'location': 'Expat International', 'url': 'https://londonreal.tv/', 'description': '#Investigative #Journalist #DeepState #NWO #FreeSpeech #LondonRealArmy #Media #Sport #Agent #Politics #Recruitment  #Wind #Oil #CFC #KTBFFH💙', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1136, 'friends_count': 4998, 'listed_count': 19, 'favourites_count': 34014, 'statuses_count': 28425, 'created_at': 'Thu Feb 24 11:03:56 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/570798172467040256/BQn7FzKV_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/570798172467040256/BQn7FzKV_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/256933322/1524332060', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon May 18 09:24:21 +0000 2020', 'id': 1262313062968832000, 'id_str': '1262313062968832000', 'text': "You can see how deep the #BillGates/#Fauci agenda has penetrated the states now. Here's one dissenting voice from… https://t.co/SSzJVy2awe", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 16936686, 'id_str': '16936686', 'name': 'Patrick Henningsen', 'screen_name': '21WIRE', 'location': 'USA', 'url': 'https://21stCenturyWire.com', 'description': 'Independent global affairs analyst, journalist, radio host, TV broadcaster, and fierce critic of mainstream media propaganda. https://21w.co/support', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 44852, 'friends_count': 2510, 'listed_count': 576, 'favourites_count': 24118, 'statuses_count': 72303, 'created_at': 'Thu Oct 23 22:03:55 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '8B542B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'EADEAA', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1112335024437805056/4nNhsvy9_normal.png', 'profile_image_url_https': 'https://pbs.twim ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at Assassin's Creed Syndicate
# @Ubisoft @assassinscreed
#
# #VGPUnite
# #VirtualPhotography
# #AssassinsCreedSyndicate https://t.co/K9vTlXgPgt
# {'created_at': 'Mon May 18 09:28:47 +0000 2020', 'id': 1262314176816361472, 'id_str': '1262314176816361472', 'text': "Assassin's Creed Syndicate \n@Ubisoft @assassinscreed\n\n#VGPUnite\n#VirtualPhotography\n#AssassinsCreedSyndicate… https://t.co/K9vTlXgPgt", 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 985855471260086272, 'id_str': '985855471260086272', 'name': 'Muhammad Alfath Diansyah', 'screen_name': 'fathdepeace', 'location': 'Kota Bogor, Jawa Barat', 'url': 'https://instagram.com/fathdepeace', 'description': 'an INFJ-t', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 16, 'friends_count': 17, 'listed_count': 0, 'favourites_count': 401, 'statuses_count': 115, 'created_at': 'Mon Apr 16 12:20:35 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1226670035403325440/3dh6cdUa_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1226670035403325440/3dh6cdUa_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/985855471260086272/1589011400', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': "Assassin's Creed Syndicate \n@Ubisoft @assassinscreed\n\n#VGPUnite\n#VirtualPhotography\n#AssassinsCreedSyndicate #assassinscreed  #ubisoft #game #gamephotography #games #London #STAYHOME #CoronaVirus https://t.co/3GgNs305zE", 'display_text_range': [0, 195], 'entities': {'hashtags': [{'text': 'VGPUnite', 'indices': [54, 63]}, {'text': 'VirtualPhotography', 'indices': [64, 83]}, {'text': 'AssassinsCreedSyndicate', 'indices': [84, 108]}, {'text': 'assassinscreed', 'indices': [109, 124]}, {'text': 'ubisoft', 'indices': [126, 134]}, {'text': 'game', 'indices': [135, 140]}, {'text': 'gamephotography', 'indices': [141, 157]}, {'text': 'games', 'indices': [158, 164]}, {'text': 'London', 'indices': [165, 172]}, {'text': 'STAYHOME', 'indices': [173, 182]}, {'text': 'CoronaVirus', 'indices': [183, 195]}], 'urls': [], 'user_mentions': [{'screen_name': 'Ubisoft', 'name': 'Ubisoft', 'id': 14922225, 'id_str': '14922225', 'indices': [28, 36]}, {'screen_name': 'assassinscreed', 'name': "Assassin's Creed", 'id': 38232487, 'id_str': '38232487', 'indices': [37, 52]}], 'symbols': [], 'media': [{'id': 1262314128359796737, 'id_str': '1262314128359796737', 'indices': [196, 219], 'media_url': 'http://pbs.twimg.com/media/EYSkAv_XsAERQra.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EYSkAv_XsAERQra.jpg', 'url': 'https://t.co/3GgNs305zE', 'display_url': 'pic.twitter.com/3GgNs305zE', 'expanded_url': 'https://twitter.com/fathdepeace/status/1262314176816361472/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1024, 'h': 575, 'resize': 'fit'}, 'large': {'w': 1024, 'h': 575, 'resize': 'fit'}, 'small': {'w': 680, 'h': 382, 'resize': 'fit'}}}, {'id': 1262314144260374528, 'id_str': '1262314144260374528', 'indices': [196, 219], 'media_url': 'http://pbs.twimg.com/media/EYSkBrOXQAAHKxL.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EYSkBrOXQAAHKxL.jpg', 'url': 'https://t.co/3GgN ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @IndoPac_Info: Almost 120 nations have now backed an international push for a coronavirus inquiry: #Australian H. Minister Greg Hunt
#
# E
# {'created_at': 'Mon May 18 09:28:47 +0000 2020', 'id': 1262314179261693953, 'id_str': '1262314179261693953', 'text': 'RT @IndoPac_Info: Almost 120 nations have now backed an international push for a coronavirus inquiry: #Australian H. Minister Greg Hunt \n\nE…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1199005500769128448, 'id_str': '1199005500769128448', 'name': '𝑮𝒊𝒍𝒈𝒂𝒎𝒆𝒔𝒉 😷', 'screen_name': 'letmecheckcheck', 'location': None, 'url': None, 'description': '#FightForFreedom #StandWithHongKong\n#5DemandNot1Less #FollowBackHongKong\n#Prepper #Parkour\n\nSolve et coagula\n\nFollow/RT/Like≠Agree', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1066, 'friends_count': 2356, 'listed_count': 2, 'favourites_count': 22480, 'statuses_count': 15917, 'created_at': 'Mon Nov 25 16:42:57 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1215187913954082816/KZebTwEP_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1215187913954082816/KZebTwEP_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1199005500769128448/1583269843', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon May 18 03:16:40 +0000 2020', 'id': 1262220534294564864, 'id_str': '1262220534294564864', 'text': 'Almost 120 nations have now backed an international push for a coronavirus inquiry: #Australian H. Minister Greg Hu… https://t.co/MkD8s7tl1f', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 844136511079559168, 'id_str': '844136511079559168', 'name': 'Indo-Pacific News', 'screen_name': 'IndoPac_Info', 'location': 'South East Asia', 'url': None, 'description': 'Spanish man in Asia observing the geo-strategic & military balance of power between #China & its opponents in the #IndoPacific\n \nSupport #HongKong & #Taiwan 💪', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 31146, 'friends_count': 389, 'listed_count': 411, 'favourites_count': 56980, 'statuses_count': 80839, 'created_at': 'Tue Mar 21 10:40:02 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1198135061553377282/bwqfrgWn_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1198135061553377282/bwqfrgWn_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/ ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @aus_business: #coronavirus retail changes mean Cotton On has had about half its 300 new jobs go to existing staff redeployed from the c
# {'created_at': 'Mon May 18 09:28:47 +0000 2020', 'id': 1262314179496566784, 'id_str': '1262314179496566784', 'text': 'RT @aus_business: #coronavirus retail changes mean Cotton On has had about half its 300 new jobs go to existing staff redeployed from the c…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 59660769, 'id_str': '59660769', 'name': 'Rachel Baxendale', 'screen_name': 'rachelbaxendale', 'location': 'Melbourne, via CBR & NE Vic', 'url': 'http://www.theaustralian.com.au/author/Rachel+Baxendale', 'description': 'Victorian Political Reporter for The @australian. Previously in our Canberra bureau. Wine Science student @CharlesSturtUni. baxendale@theaustralian.com.au', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 7490, 'friends_count': 5162, 'listed_count': 181, 'favourites_count': 4554, 'statuses_count': 8686, 'created_at': 'Fri Jul 24 02:10:21 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1186173577701101568/tNqIShHS_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1186173577701101568/tNqIShHS_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/59660769/1450949087', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon May 18 09:28:27 +0000 2020', 'id': 1262314095824343041, 'id_str': '1262314095824343041', 'text': '#coronavirus retail changes mean Cotton On has had about half its 300 new jobs go to existing staff redeployed from… https://t.co/YuqkFs7V0W', 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 26192899, 'id_str': '26192899', 'name': 'Business Review', 'screen_name': 'aus_business', 'location': 'Australia', 'url': 'https://www.theaustralian.com.au/business', 'description': 'Latest business news from The Australian Business Review', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 42199, 'friends_count': 285, 'listed_count': 829, 'favourites_count': 212, 'statuses_count': 104086, 'created_at': 'Tue Mar 24 06:50:08 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1199264225387896832/NKLxAkkc_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1199264225387896832/NKLxAkkc_nor ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @guy_ingerson: Looks like our @ScotGP MSPs (with your support!) have won a big concession from the Scottish Government.
#
# Tax dodging co
# {'created_at': 'Mon May 18 09:28:48 +0000 2020', 'id': 1262314182776586240, 'id_str': '1262314182776586240', 'text': 'RT @guy_ingerson: Looks like our @ScotGP MSPs (with your support!) have won a big concession from the Scottish Government. \n\nTax dodging co…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 842485106, 'id_str': '842485106', 'name': 'Kyle', 'screen_name': 'ko_oneill', 'location': ' ', 'url': 'https://www.instagram.com/kyle_on91/', 'description': '👤👈 thinking 👉👣 dancing| Mojitos. \n\nRBMK reactor truther account.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 466, 'friends_count': 950, 'listed_count': 12, 'favourites_count': 24647, 'statuses_count': 20964, 'created_at': 'Sun Sep 23 22:09:31 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1080529474414919680/HUHyIFBH_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080529474414919680/HUHyIFBH_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/842485106/1552335980', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon May 18 09:19:00 +0000 2020', 'id': 1262311715573817344, 'id_str': '1262311715573817344', 'text': 'Looks like our @ScotGP MSPs (with your support!) have won a big concession from the Scottish Government. \n\nTax dodg… https://t.co/CBPyoaCteZ', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 800793414585323520, 'id_str': '800793414585323520', 'name': 'Guy Ingerson', 'screen_name': 'guy_ingerson', 'location': 'Aberdeen, Scotland', 'url': 'https://www.facebook.com/IngersonGuy/', 'description': 'Candidate for North East Scotland @ScotGP | Convenor @AberdeenGreens | Co-Convenor @RainbowGreens | Key Worker @UsdawUnion | Eco-Socialist | He/Him', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2350, 'friends_count': 2182, 'listed_count': 27, 'favourites_count': 68746, 'statuses_count': 7395, 'created_at': 'Mon Nov 21 20:10:02 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1211326773578911746/6usoV4V9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211326773578911746/6usoV4V9_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/800793414585323520/1570468744', 'defaul ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @HERoS_EU: The #EU-funded #HERoS_EU project is online now! Have a look at the dedicated website to find out more about the project, its
# ...
# 1
# 2
# 3
# 4
# 5
# Tweet collected at Covering a wide range of #coronavirus topics, our recommended reading on #Covid19 in #LatinAmerica includes pieces https://t.co/tXqTB3TDoO
# {'created_at': 'Mon May 18 09:29:34 +0000 2020', 'id': 1262314374791942144, 'id_str': '1262314374791942144', 'text': 'Covering a wide range of #coronavirus topics, our recommended reading on #Covid19 in #LatinAmerica includes pieces… https://t.co/tXqTB3TDoO', 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 280565933, 'id_str': '280565933', 'name': 'Canning House', 'screen_name': 'Canning_House', 'location': '126 Wigmore Street, London', 'url': 'http://www.canninghouse.org', 'description': 'The UK’s leading forum for contacts, thought-leadership and pragmatic debate on Latin American politics, economics, business and culture since 1943.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 4092, 'friends_count': 1536, 'listed_count': 91, 'favourites_count': 1088, 'statuses_count': 10617, 'created_at': 'Mon Apr 11 15:47:15 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1201444042422263809/YEIfhVuf_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1201444042422263809/YEIfhVuf_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/280565933/1561046341', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Covering a wide range of #coronavirus topics, our recommended reading on #Covid19 in #LatinAmerica includes pieces from @TheWilsonCenter, @KingsBrazil, @the_IDB &amp; more - with excellent articles, webinars and guidance.\n\nSee our recommendations &gt;&gt;\n\nhttps://t.co/xFnUavnoST', 'display_text_range': [0, 280], 'entities': {'hashtags': [{'text': 'coronavirus', 'indices': [25, 37]}, {'text': 'Covid19', 'indices': [73, 81]}, {'text': 'LatinAmerica', 'indices': [85, 98]}], 'urls': [{'url': 'https://t.co/xFnUavnoST', 'expanded_url': 'https://www.canninghouse.org/news/covid-19-in-latin-america', 'display_url': 'canninghouse.org/news/covid-19-…', 'indices': [257, 280]}], 'user_mentions': [{'screen_name': 'TheWilsonCenter', 'name': 'The Wilson Center', 'id': 382129509, 'id_str': '382129509', 'indices': [120, 136]}, {'screen_name': 'KingsBrazil', 'name': "King's Brazil Institute", 'id': 335926528, 'id_str': '335926528', 'indices': [138, 150]}, {'screen_name': 'the_IDB', 'name': 'Inter-American Development Bank', 'id': 18509466, 'id_str': '18509466', 'indices': [152, 160]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'coronavirus', 'indices': [25, 37]}, {'text': 'Covid19', 'indices': [73, 81]}, {'text': 'LatinAmerica', 'indices': [85, 98]}], 'urls': [{'url': 'https://t.co/tXqTB3TDoO', 'expanded_url': 'https://twitter.com/i/web/status/1262314374791942144', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1589794174274'}
# 1
# 2
# 3
# 4
# 5
# Tweet collected at RT @KTHopkins: If you have death threats for me, need to swear at me, threaten violence against my family, tell me what a NHS hero you are
# {'created_at': 'Mon May 18 09:29:34 +0000 2020', 'id': 1262314375400038400, 'id_str': '1262314375400038400', 'text': 'RT @KTHopkins: If you have death threats for me, need to swear at me, threaten violence against my family, tell me what a NHS hero you are…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1247643567117475843, 'id_str': '1247643567117475843', 'name': 'Jairzinho “The Future” Rozenstruik', 'screen_name': 'UFCMasterMind', 'location': 'Croydon, London', 'url': 'http://cunt.com', 'description': 'Shag birds for a living. Tell it how it is. Representing Future UFC Heavyweight Champion Jairzinho Rozenstruik', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 88, 'friends_count': 267, 'listed_count': 0, 'favourites_count': 136, 'statuses_count': 1296, 'created_at': 'Tue Apr 07 21:53:07 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1262073874272989184/t12iHTul_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1262073874272989184/t12iHTul_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1247643567117475843/1589723999', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun May 17 20:04:27 +0000 2020', 'id': 1262111763199414274, 'id_str': '1262111763199414274', 'text': 'If you have death threats for me, need to swear at me, threaten violence against my family, tell me what a NHS hero… https://t.co/vvB0dPI9ZM', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 21439144, 'id_str': '21439144', 'name': 'Katie Hopkins', 'screen_name': 'KTHopkins', 'location': 'Omnipresent ', 'url': 'http://www.frontpagemag.com', 'description': '“much prettier in person”  “smaller than I expected” “hung like a baboon” “face like a Netflix box set in one place”', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 1091927, 'friends_count': 72, 'listed_count': 3082, 'favourites_count': 21, 'statuses_count': 33452, 'created_at': 'Fri Feb 20 22:01:54 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FF33CC', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '0004FA', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '00CCFF', 'profile_text_color': '050505', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/915081489573974016/esP5WVn-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915081489573974016/esP5WVn-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21439144/1565370706' ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1778e64f019e> in <module>
#       1 MyListener = MyListener(api=tweepy.API(wait_on_rate_limit=True))
#       2 myStream = tweepy.Stream(auth = api.auth, listener = MyListener )
# ----> 3 myStream.filter(languages=["en"], track = ['#coronavirus'])
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /Applications/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# /Applications/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# /Applications/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
